# %% [markdown]
# # Capstone Project-5
# ## Domain:
# - Marketing for Financial Services
# ## Title:
# - Exploratory Data Analysis and Predictive Modeling for Marketing Term-Deposit Scheme in the Financial Services Industry
# ## About:
# - DB Bank is a large public sector bank that has branches across the cities. It provides various services like savings accounts, current accounts, term deposits, personal loans, home loans, etc. to customers. Whenever the bank conducts marketing on its new schemes, it will keep track of data related to customers’ personal, social, and economic details. Also, it maintains the detailing of efforts made to achieve success in the campaign. Recently, the bank has conducted a campaign to market its term-deposit scheme. Campaigns were conducted based mostly on direct phone calls, soliciting the bank's customers to place  a term deposit. After all the marketing efforts, if the client had agreed to place a deposit, then the campaign is a success, otherwise not (Target variable marked 'yes', or 'no').

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd      # Data manipulation and analysis
import numpy as np       # Mathematical functions and arrays
# %matplotlib inline 
import matplotlib.pyplot as plt   # Basic plotting
import seaborn as sns     # Statistical data visualization
import plotly.graph_objects as go   # Interactive plots
import plotly.express as px   # Expressive visualizations
import folium     # Geospatial data visualization

# %% [markdown]
# ## Importing datasets and data cleanup

# %%
Y = pd.read_csv('Customer_Response_data_p1.csv') # the output (Yes/No)
Customer_and_bank_details_p1 = pd.read_csv('Customer_and_bank details_p1.csv')
Customer_campaign_details_p1 = pd.read_csv('Customer_campaign_details_p1.csv')
Customer_Postal_Code_detail = pd.read_csv('Customer_Postal_Code_details.csv')
Customer_social_economic_data_p1 = pd.read_csv('Customer_social_economic_data_p1.csv')
State_Master = pd.read_csv('State_Master.csv')
Region_code_master = pd.read_csv('Region_code_master.csv')
City_Master = pd.read_csv('City_Master.csv')

# %% [markdown]
# ## Exploring data
# In this section we explore the different datasets and how they are related.

# %%
Customer_and_bank_details_p1.head(3)
# Out:
#    Customer_id  age    job    marital       education       default  housing  \
# 0       1       56   services  married          high.school       no    no
# 1       2       45   services  married             basic.9y  unknown    no
# 2       3       59     admin.  married  professional.course       no    no
#
#   loan Region_Code State_Code City_Code
# 0  yes       3         S1         C1
# 1   no       3         S1         C1
# 2   no       4         S2         C2

# %%
Customer_and_bank_details_p1.describe()
# Out:
#         Customer_id       age
# count  37084.000000  37084.000000
# mean   18542.500000     40.042714
# std    10705.373028     10.432965
# min        1.000000     17.000000
# 25%     9271.750000     32.000000
# 50%    18542.500000     38.000000
# 75%    27813.250000     47.000000
# max    37084.000000     98.000000

# %%
Customer_and_bank_details_p1.isnull().sum()
# Out:
# Customer_id    0
# age            0
# job            0
# marital        0
# education      0
# default        0
# housing        0
# loan           0
# Region_Code    0
# State_Code     0
# City_Code      0
# dtype: int64

# %%
Customer_campaign_details_p1.head(3)
# Out:
#    Customer_id  contact   month day_of_week  duration  campaign  pdays  \
# 0       1       telephone   may      mon        307        1      999
# 1       2       telephone   may      mon        198        1      999
# 2       3       telephone   may      mon        139        1      999
#
#    previous   poutcome
# 0      0     nonexistent
# 1      0     nonexistent
# 2      0     nonexistent

# %%
Customer_campaign_details_p1.describe()
# Out:
#         Customer_id    duration      campaign        pdays       previous
# count  37084.000000  37084.000000  37084.000000  37084.000000  37084.000000
# mean   18542.500000    258.237946      2.569545    962.530849      0.172986
# std    10705.373028    258.730909      2.770611    186.773063      0.495681
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%     9271.750000    102.000000      1.000000    999.000000      0.000000
# 50%    18542.500000    180.000000      2.000000    999.000000      0.000000
# 75%    27813.250000    319.250000      3.000000    999.000000      0.000000
# max    37084.000000   4918.000000     56.000000    999.000000      7.000000

# %%
Customer_campaign_details_p1.isnull().sum()
# Out:
# Customer_id    0
# contact        0
# month          0
# day_of_week    0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# dtype: int64

# %%
Customer_Postal_Code_detail.head(3)
# Out:
#    customer_id  Postal Code
# 0       1          42420
# 1       2          42420
# 2       3          90036

# %%
Customer_Postal_Code_detail.describe()
# Out:
#         customer_id   Postal Code
# count  37084.000000  37084.000000
# mean   18542.500000  55202.625553
# std    10705.373028  32057.300954
# min        1.000000   1040.000000
# 25%     9271.750000  23223.000000
# 50%    18542.500000  56301.000000
# 75%    27813.250000  90008.000000
# max    37084.000000  99301.000000

# %%
Customer_Postal_Code_detail.isnull().sum()
# Out:
# customer_id    0
# Postal Code    0
# dtype: int64

# %%
Customer_social_economic_data_p1.head(3)
# Out:
#    Customer_id  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0       1            1.1          93.994         -36.4         4.857
# 1       2            1.1          93.994         -36.4         4.857
# 2       3            1.1          93.994         -36.4         4.857
#
#    nr.employed
# 0    5191.0
# 1    5191.0
# 2    5191.0

# %%
Customer_social_economic_data_p1.describe()
# Out:
#         Customer_id  emp.var.rate  cons.price.idx  cons.conf.idx  \
# count  37084.000000  37084.000000   37084.000000   37084.000000
# mean   18542.500000      0.082669      93.576076     -40.505183
# std    10705.373028      1.568997       0.578493       4.622045
# min        1.000000     -3.400000      92.201000     -50.800000
# 25%     9271.750000     -1.800000      93.075000     -42.700000
# 50%    18542.500000      1.100000      93.749000     -41.800000
# 75%    27813.250000      1.400000      93.994000     -36.400000
# max    37084.000000      1.400000      94.767000     -26.900000
#
#          euribor3m    nr.employed
# count  37084.000000  37084.000000
# mean       3.621668   5167.058664
# std        1.733972     72.196605
# min        0.634000   4963.600000
# 25%        1.344000   5099.100000
# 50%        4.857000   5191.000000
# 75%        4.961000   5228.100000
# max        5.045000   5228.100000

# %%
Customer_social_economic_data_p1.isnull().sum()
# Out:
# Customer_id       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# dtype: int64

# %%
data = pd.merge(Customer_and_bank_details_p1,Customer_campaign_details_p1 , on='Customer_id', how='outer')
data
# Out:
#        Customer_id  age     job      marital       education       default   \
# 0             1     56      services  married          high.school       no
# 1             2     45      services  married             basic.9y  unknown
# 2             3     59        admin.  married  professional.course       no
# 3             4     41   blue-collar  married              unknown  unknown
# 4             5     24    technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079     37080     73       retired  married  professional.course       no
# 37080     37081     46   blue-collar  married  professional.course       no
# 37081     37082     56       retired  married    university.degree       no
# 37082     37083     44    technician  married  professional.course       no
# 37083     37084     74       retired  married  professional.course       no
#
#       housing loan Region_Code State_Code City_Code  contact   month  \
# 0         no   yes       3          S1         C1    telephone   may
# 1         no    no       3          S1         C1    telephone   may
# 2         no    no       4          S2         C2    telephone   may
# 3         no    no       3          S3         C3    telephone   may
# 4        yes    no       3          S3         C3    telephone   may
# ...       ...  ...         ...        ...       ...        ...   ...
# 37079    yes    no       2         S16        C21     cellular   nov
# 37080     no    no       2         S16        C21     cellular   nov
# 37081    yes    no       2         S16        C21     cellular   nov
# 37082     no    no       4         S17        C49     cellular   nov
# 37083    yes    no       1          S6       C113     cellular   nov
#
#       day_of_week  duration  campaign  pdays  previous   poutcome
# 0          mon        307        1      999       0     nonexistent
# 1          mon        198        1      999       0     nonexistent
# 2          mon        139        1      999       0     nonexistent
# 3          mon        217        1      999       0     nonexistent
# 4          mon        380        1      999       0     nonexistent
# ...           ...       ...       ...    ...       ...          ...
# 37079      fri        334        1      999       0     nonexistent
# 37080      fri        383        1      999       0     nonexistent
# 37081      fri        189        2      999       0     nonexistent
# 37082      fri        442        1      999       0     nonexistent
# 37083      fri        239        3      999       1         failure
#
# [37084 rows x 19 columns]

# %%
Customer_Postal_Code_detail = Customer_Postal_Code_detail.rename(columns={'customer_id':'Customer_id'})

# %% [markdown]
# Starting to merge all the different datasets into one big dataset

# %%
data = pd.merge(data,Customer_Postal_Code_detail , on='Customer_id', how='outer')
data.head(3)
# Out:
#    Customer_id  age    job    marital       education       default  housing  \
# 0       1       56   services  married          high.school       no    no
# 1       2       45   services  married             basic.9y  unknown    no
# 2       3       59     admin.  married  professional.course       no    no
#
#   loan Region_Code State_Code City_Code  contact   month day_of_week  \
# 0  yes       3         S1         C1     telephone   may      mon
# 1   no       3         S1         C1     telephone   may      mon
# 2   no       4         S2         C2     telephone   may      mon
#
#    duration  campaign  pdays  previous   poutcome    Postal Code
# 0     307        1      999       0     nonexistent     42420
# 1     198        1      999       0     nonexistent     42420
# 2     139        1      999       0     nonexistent     90036

# %%
#Customer_social_economic_data_p1
data = pd.merge(data,Customer_social_economic_data_p1, on='Customer_id', how='outer')
data.head(3)
# Out:
#    Customer_id  age    job    marital       education       default  housing  \
# 0       1       56   services  married          high.school       no    no
# 1       2       45   services  married             basic.9y  unknown    no
# 2       3       59     admin.  married  professional.course       no    no
#
#   loan Region_Code State_Code City_Code  contact   month day_of_week  \
# 0  yes       3         S1         C1     telephone   may      mon
# 1   no       3         S1         C1     telephone   may      mon
# 2   no       4         S2         C2     telephone   may      mon
#
#    duration  campaign  pdays  previous   poutcome    Postal Code  \
# 0     307        1      999       0     nonexistent     42420
# 1     198        1      999       0     nonexistent     42420
# 2     139        1      999       0     nonexistent     90036
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0       1.1          93.994         -36.4         4.857      5191.0
# 1       1.1          93.994         -36.4         4.857      5191.0
# 2       1.1          93.994         -36.4         4.857      5191.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37084 entries, 0 to 37083
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_id     37084 non-null  int64
#  1   age             37084 non-null  int64
#  2   job             37084 non-null  object
#  3   marital         37084 non-null  object
#  4   education       37084 non-null  object
#  5   default         37084 non-null  object
#  6   housing         37084 non-null  object
#  7   loan            37084 non-null  object
#  8   Region_Code     37084 non-null  object
#  9   State_Code      37084 non-null  object
#  10  City_Code       37084 non-null  object
#  11  contact         37084 non-null  object
#  12  month           37084 non-null  object
#  13  day_of_week     37084 non-null  object
#  14  duration        37084 non-null  int64
#  15  campaign        37084 non-null  int64
#  16  pdays           37084 non-null  int64
#  17  previous        37084 non-null  int64
#  18  poutcome        37084 non-null  object
#  19  Postal Code     37084 non-null  int64
#  20  emp.var.rate    37084 non-null  float64
#  21  cons.price.idx  37084 non-null  float64
#  22  cons.conf.idx   37084 non-null  float64
#  23  euribor3m       37084 non-null  float64
#  24  nr.employed     37084 non-null  float64
# dtypes: float64(5), int64(7), object(13)
# memory usage: 7.4+ MB

# %% [markdown]
# # Now we have a compound dataframe

# %%
# importing label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

Y['y'] = le.fit_transform(df_copy['y'])
Y
# Out:
#        Customer_id  y
# 0             1     0
# 1             2     0
# 2             3     0
# 3             4     0
# 4             5     0
# ...            ... ..
# 37079     37080     1
# 37080     37081     0
# 37081     37082     0
# 37082     37083     1
# 37083     37084     0
#
# [37084 rows x 2 columns]

# %%
data = pd.merge(data,Y, on='Customer_id', how='outer')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import copy
df = copy.deepcopy(data)  # get a copy variable for our main data, so that we have room to experiment
df.head()
# Out:
#    Customer_id  age     job      marital       education       default   \
# 0       1       56      services  married          high.school       no
# 1       2       45      services  married             basic.9y  unknown
# 2       3       59        admin.  married  professional.course       no
# 3       4       41   blue-collar  married              unknown  unknown
# 4       5       24    technician   single  professional.course       no
#
#   housing loan Region_Code State_Code City_Code  contact   month day_of_week  \
# 0     no   yes       3         S1         C1     telephone   may      mon
# 1     no    no       3         S1         C1     telephone   may      mon
# 2     no    no       4         S2         C2     telephone   may      mon
# 3     no    no       3         S3         C3     telephone   may      mon
# 4    yes    no       3         S3         C3     telephone   may      mon
#
#    duration  campaign  pdays  previous   poutcome    Postal Code  \
# 0     307        1      999       0     nonexistent     42420
# 1     198        1      999       0     nonexistent     42420
# 2     139        1      999       0     nonexistent     90036
# 3     217        1      999       0     nonexistent     33311
# 4     380        1      999       0     nonexistent     33311
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed y_x  \
# 0       1.1          93.994         -36.4         4.857      5191.0     no
# 1       1.1          93.994         -36.4         4.857      5191.0     no
# 2       1.1          93.994         -36.4         4.857      5191.0     no
# 3       1.1          93.994         -36.4         4.857      5191.0     no
# 4       1.1          93.994         -36.4         4.857      5191.0     no
#
#    y_y
# 0   0
# 1   0
# 2   0
# 3   0
# 4   0

# %%
df.isnull().sum()
# Out:
# Customer_id       0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# Region_Code       0
# State_Code        0
# City_Code         0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# Postal Code       0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y_x               0
# y_y               0
# dtype: int64

# %%
df.shape
# Out:
# (37084, 27)

# %% [markdown]
# # Tranformation of dataframe from object type to numeric type

# %%
# we want to do the datatype conversion on a second copy so that we dont harm our previous work
df_copy = copy.deepcopy(df)

# %%
df_copy
# Out:
#        Customer_id  age     job      marital       education       default   \
# 0             1     56      services  married          high.school       no
# 1             2     45      services  married             basic.9y  unknown
# 2             3     59        admin.  married  professional.course       no
# 3             4     41   blue-collar  married              unknown  unknown
# 4             5     24    technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079     37080     73       retired  married  professional.course       no
# 37080     37081     46   blue-collar  married  professional.course       no
# 37081     37082     56       retired  married    university.degree       no
# 37082     37083     44    technician  married  professional.course       no
# 37083     37084     74       retired  married  professional.course       no
#
#       housing loan Region_Code State_Code City_Code  contact   month  \
# 0         no   yes       3          S1         C1    telephone   may
# 1         no    no       3          S1         C1    telephone   may
# 2         no    no       4          S2         C2    telephone   may
# 3         no    no       3          S3         C3    telephone   may
# 4        yes    no       3          S3         C3    telephone   may
# ...       ...  ...         ...        ...       ...        ...   ...
# 37079    yes    no       2         S16        C21     cellular   nov
# 37080     no    no       2         S16        C21     cellular   nov
# 37081    yes    no       2         S16        C21     cellular   nov
# 37082     no    no       4         S17        C49     cellular   nov
# 37083    yes    no       1          S6       C113     cellular   nov
#
#       day_of_week  duration  campaign  pdays  previous   poutcome    \
# 0          mon        307        1      999       0     nonexistent
# 1          mon        198        1      999       0     nonexistent
# 2          mon        139        1      999       0     nonexistent
# 3          mon        217        1      999       0     nonexistent
# 4          mon        380        1      999       0     nonexistent
# ...           ...       ...       ...    ...       ...          ...
# 37079      fri        334        1      999       0     nonexistent
# 37080      fri        383        1      999       0     nonexistent
# 37081      fri        189        2      999       0     nonexistent
# 37082      fri        442        1      999       0     nonexistent
# 37083      fri        239        3      999       1         failure
#
#        Postal Code  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0         42420          1.1          93.994         -36.4         4.857
# 1         42420          1.1          93.994         -36.4         4.857
# 2         90036          1.1          93.994         -36.4         4.857
# 3         33311          1.1          93.994         -36.4         4.857
# 4         33311          1.1          93.994         -36.4         4.857
# ...            ...           ...             ...            ...        ...
# 37079     10009         -1.1          94.767         -50.8         1.028
# 37080     10011         -1.1          94.767         -50.8         1.028
# 37081     10009         -1.1          94.767         -50.8         1.028
# 37082     85254         -1.1          94.767         -50.8         1.028
# 37083     79109         -1.1          94.767         -50.8         1.028
#
#        nr.employed y_x   y_y
# 0        5191.0      no   0
# 1        5191.0      no   0
# 2        5191.0      no   0
# 3        5191.0      no   0
# 4        5191.0      no   0
# ...            ...  ...  ...
# 37079    4963.6     yes   1
# 37080    4963.6      no   0
# 37081    4963.6      no   0
# 37082    4963.6     yes   1
# 37083    4963.6      no   0
#
# [37084 rows x 27 columns]

# %% [markdown]
# # Raw data dsecription

# %%
data.describe(include="all")
# Out:
#          Customer_id       age       job   marital      education       \
# count   37084.000000  37084.000000   37084    37084              37084
# unique           NaN           NaN      12        4                  8
# top              NaN           NaN  admin.  married  university.degree
# freq             NaN           NaN    9420    22479              10971
# mean    18542.500000     40.042714     NaN      NaN                NaN
# std     10705.373028     10.432965     NaN      NaN                NaN
# min         1.000000     17.000000     NaN      NaN                NaN
# 25%      9271.750000     32.000000     NaN      NaN                NaN
# 50%     18542.500000     38.000000     NaN      NaN                NaN
# 75%     27813.250000     47.000000     NaN      NaN                NaN
# max     37084.000000     98.000000     NaN      NaN                NaN
#
#        default housing  loan  Region_Code State_Code City_Code  contact   \
# count    37084   37084  37084     37084      37084      37084      37084
# unique       3       3      3         5         49        531          2
# top         no     yes     no         4         S2        C21   cellular
# freq     29382   19433  30561     11884       7427       3422      23522
# mean       NaN     NaN    NaN       NaN        NaN        NaN        NaN
# std        NaN     NaN    NaN       NaN        NaN        NaN        NaN
# min        NaN     NaN    NaN       NaN        NaN        NaN        NaN
# 25%        NaN     NaN    NaN       NaN        NaN        NaN        NaN
# 50%        NaN     NaN    NaN       NaN        NaN        NaN        NaN
# 75%        NaN     NaN    NaN       NaN        NaN        NaN        NaN
# max        NaN     NaN    NaN       NaN        NaN        NaN        NaN
#
#        month  day_of_week    duration      campaign        pdays     \
# count   37084     37084    37084.000000  37084.000000  37084.000000
# unique     10         5             NaN           NaN           NaN
# top       may       thu             NaN           NaN           NaN
# freq    12420      7778             NaN           NaN           NaN
# mean      NaN       NaN      258.237946      2.569545    962.530849
# std       NaN       NaN      258.730909      2.770611    186.773063
# min       NaN       NaN        0.000000      1.000000      0.000000
# 25%       NaN       NaN      102.000000      1.000000    999.000000
# 50%       NaN       NaN      180.000000      2.000000    999.000000
# 75%       NaN       NaN      319.250000      3.000000    999.000000
# max       NaN       NaN     4918.000000     56.000000    999.000000
#
#           previous     poutcome     Postal Code  emp.var.rate  cons.price.idx  \
# count   37084.000000        37084  37084.000000  37084.000000   37084.000000
# unique           NaN            3           NaN           NaN            NaN
# top              NaN  nonexistent           NaN           NaN            NaN
# freq             NaN        32023           NaN           NaN            NaN
# mean        0.172986          NaN  55202.625553      0.082669      93.576076
# std         0.495681          NaN  32057.300954      1.568997       0.578493
# min         0.000000          NaN   1040.000000     -3.400000      92.201000
# 25%         0.000000          NaN  23223.000000     -1.800000      93.075000
# 50%         0.000000          NaN  56301.000000      1.100000      93.749000
# 75%         0.000000          NaN  90008.000000      1.400000      93.994000
# max         7.000000          NaN  99301.000000      1.400000      94.767000
#
#         cons.conf.idx    euribor3m    nr.employed  y_x         y_y
# count   37084.000000   37084.000000  37084.000000  37084  37084.000000
# unique           NaN            NaN           NaN      2           NaN
# top              NaN            NaN           NaN     no           NaN
# freq             NaN            NaN           NaN  32876           NaN
# mean      -40.505183       3.621668   5167.058664    NaN      0.113472
# std         4.622045       1.733972     72.196605    NaN      0.317173
# min       -50.800000       0.634000   4963.600000    NaN      0.000000
# 25%       -42.700000       1.344000   5099.100000    NaN      0.000000
# 50%       -41.800000       4.857000   5191.000000    NaN      0.000000
# 75%       -36.400000       4.961000   5228.100000    NaN      0.000000
# max       -26.900000       5.045000   5228.100000    NaN      1.000000

# %%
columns = ['Customer_id', 'age', 'job', 'marital', 'education', 'default',
       'housing', 'loan', 'Region_Code', 'State_Code', 'City_Code', 'contact',
       'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous',
       'poutcome', 'Postal Code', 'emp.var.rate', 'cons.price.idx',
       'cons.conf.idx', 'euribor3m', 'nr.employed', 'y_x', 'y_y']
# Out:
# 0         S1
# 1         S1
# 2         S2
# 3         S3
# 4         S3
#         ...
# 37079    S16
# 37080    S16
# 37081    S16
# 37082    S17
# 37083     S6
# Name: State_Code, Length: 37084, dtype: object

# %% [markdown]
# # correlation of all ctegorical and numeric data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for column in df_copy.columns:
    if df_copy[column].dtype == 'object':
        df_copy[column] = le.fit_transform(df_copy[column])

# %%
matrix = df_copy.corr()
plt.figure(figsize=(25,25))
sns.heatmap(matrix,vmax=.8,square=False,cmap='YlGnBu', annot = True,linewidths= 1 ,fmt=".3f")
# Out:
# <Axes: >

# %%
to_drop = ['Region_Code', 'State_Code', 'City_Code','month']
